# %% [markdown]
# # 01 — Canvas persistente y ZoomedScene
#
# `SlidesControl` (de `toolkit`) combina `Slide` y `ZoomedScene` para ofrecer:
#
# - Canvas con título y número de diapositiva persistentes.
# - Métodos `wipe()` y `zoom()` para transiciones limpias.
# - Herencia de `ZoomedScene` para hacer zoom a regiones.
#
# ## Ejecutar como script (sin Jupyter)
#
# Renderiza con `manim-slides render` desde terminal:
#
# ```bash
# manim-slides render gallery/01_canvas_y_zoom.py DemoCanvasZoom -ql
# manim-slides DemoCanvasZoom
# ```
#
# ## Ejecutar en Jupyter
#
# La celda de más abajo usa `%%manim_slides` (cell magic) que solo funciona
# dentro de un Jupyter notebook en ejecución.

# %%
import sys
sys.path.insert(0, '..')

from manim import *
from manim_slides import Slide
from toolkit import SlidesControl, NORMAL_SIZE, TITLE_SIZE

# %%
class DemoCanvasZoom(SlidesControl):
    def construct(self):
        # 1) Canvas persistente: título arriba-izquierda, número abajo-izquierda
        titulo = Title("Canvas y Zoom", font_size=TITLE_SIZE).to_corner(UL)
        num = Text("1").to_corner(DL)
        self.add_to_canvas(title=titulo, slide_number=num)
        self.play(Write(titulo), Write(num))
        self.next_slide()

        # 2) Contenido principal con dos mobjects
        circulo = Circle(radius=1.5, color=BLUE).shift(LEFT * 3)
        cuadrado = Square(side_length=2, color=GREEN).shift(RIGHT * 3)
        self.play(Create(circulo), Create(cuadrado))
        self.next_slide()

        # 3) Limpiar el contenido usando wipe nativo de manim-slides
        #    (el título y el número del canvas permanecen)
        self.wipe(Group(circulo, cuadrado), Group())
        self.next_slide()

        # 4) Incrementar el contador del canvas (Transform nativo)
        old = self.canvas["slide_number"]
        new = Text("2").move_to(old)
        self.play(Transform(old, new))
        self.next_slide()

        # 5) ZoomedScene heredado: preparar un rectángulo para hacer zoom
        objetivo = Rectangle(width=2, height=2, color=YELLOW).shift(RIGHT * 3)
        self.play(Create(objetivo))
        self.next_slide()

        # 6) Activar zoom sobre el rectángulo amarillo
        zoomed_camera = self.zoomed_camera
        zoomed_display = self.zoomed_display
        zoomed_display.move_to(objetivo.get_center())
        self.activate_zooming(animate=False)
        self.next_slide()

        # 7) Salir del zoom
        self.activate_zooming(animate=True)
        self.next_slide()

        # 8) Limpiar todo al final (quitar canvas también)
        self.remove_from_canvas("title", "slide_number")
        self.wipe(self.mobjects_without_canvas, Group())
        self.wait()

# %% [markdown]
# ## Renderizar en Jupyter (cell magic)
#
# La siguiente celda solo funciona dentro de un Jupyter notebook en ejecución.
# Produce un iframe con la presentación RevealJS.

# %%
from manim_slides import ManimSlidesMagic  # Habilita %%manim_slides

# %%manim_slides -v WARNING --progress_bar None DemoCanvasZoom --manim-slides controls=true

class DemoCanvasZoom(SlidesControl):
    def construct(self):
        titulo = Title("Canvas y Zoom", font_size=TITLE_SIZE).to_corner(UL)
        num = Text("1").to_corner(DL)
        self.add_to_canvas(title=titulo, slide_number=num)
        self.play(Write(titulo), Write(num))
        self.next_slide()

        circulo = Circle(radius=1.5, color=BLUE).shift(LEFT * 3)
        cuadrado = Square(side_length=2, color=GREEN).shift(RIGHT * 3)
        self.play(Create(circulo), Create(cuadrado))
        self.next_slide()

        self.wipe(Group(circulo, cuadrado), Group())
        self.next_slide()

        old = self.canvas["slide_number"]
        new = Text("2").move_to(old)
        self.play(Transform(old, new))
        self.next_slide()

        objetivo = Rectangle(width=2, height=2, color=YELLOW).shift(RIGHT * 3)
        self.play(Create(objetivo))
        self.next_slide()

        zoomed_display = self.zoomed_display
        zoomed_display.move_to(objetivo.get_center())
        self.activate_zooming(animate=False)
        self.next_slide()

        self.activate_zooming(animate=True)
        self.next_slide()

        self.remove_from_canvas("title", "slide_number")
        self.wipe(self.mobjects_without_canvas, Group())
        self.wait()
