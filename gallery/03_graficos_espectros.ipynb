# %% [markdown]
# # 03 — Gráficos de espectros
#
# `ManimGraph` envuelve la creación de ejes, graficado de datos desde
# archivos y leyendas en una sola clase.
#
# ## Formato esperado
#
# Archivo de 2 columnas (x, y) sin encabezado, separado por espacios o
# tabulaciones. Si tiene encabezado, usa `pandas` (incluido como fallback).
#
# ## Requisitos
#
# - `numpy`
# - `scipy` (para `savgol_filter` cuando `smooth=True`)

# %%
import sys
sys.path.insert(0, '..')

import numpy as np

from manim import *
from manim_slides import Slide, ManimSlidesMagic 
from toolkit import ManimGraph
# Out:
# [06/24/26 13:49:11] INFO     Enabling RDKit 2026.03.3 jupyter extensions                             ]8;id=10376440;file:///home/david-ibarra/miniconda3/envs/manim/lib/python3.14/site-packages/rdkit/__init__.py\__init__.py]8;;\:]8;id=10376441;file:///home/david-ibarra/miniconda3/envs/manim/lib/python3.14/site-packages/rdkit/__init__.py#22\22]8;;\

# %%
# Generar datos sintéticos para probar sin un archivo real
rng = np.random.default_rng(42)
x = np.linspace(300, 800, 200)
y = np.exp(-((x - 500) ** 2) / (2 * 30 ** 2)) + 0.1 * rng.random(200)
data_path = "/tmp/espectro_demo.txt"
np.savetxt(data_path, np.column_stack([x, y]))
print(f"Datos guardados en {data_path}")
# Out:
# Datos guardados en /tmp/espectro_demo.txt

# %%
class DemoEspectro(Slide):
    def construct(self):
        # Título persistente entre diapositivas
        titulo = Title("Espectro de absorción").to_corner(UL)
        self.play(Write(titulo))
        self.next_slide()

        helper = ManimGraph(self)
        axes = helper.setup_axes(
            x_label=r"\lambda \,(\mathrm{nm})",
            y_label="Absorbancia",
            x_range=[300, 800, 50],
            y_range=[0, 1.2, 0.2],
        )
        self.play(Create(axes))
        self.next_slide()

        # 1) Graficar curva cruda
        curva_cruda = helper.plot_spectrum(data_path, color=BLUE, smooth=False)
        self.play(Create(curva_cruda), run_time=2)
        self.next_slide()

        # 2) Graficar curva suavizada encima
        curva_suave = helper.plot_spectrum(data_path, color=GREEN, smooth=True)
        self.play(Create(curva_suave), run_time=2)
        self.next_slide()

        # 3) Añadir leyenda con ambas curvas
        leyenda = helper.create_legend([
            {"text": "Crudo", "color": BLUE},
            {"text": "Suavizado (Savitzky-Golay)", "color": GREEN},
        ], position=UR)
        self.play(Write(leyenda))
        self.next_slide()

        # 4) Marcar el máximo (anotación para destacar la utilidad del suavizado)
        idx_max = int(np.argmax(y))
        x_max, y_max = x[idx_max], y[idx_max]
        punto_max = Dot(helper.axes.coords_to_point(x_max, y_max), color=RED)
        etiqueta_max = MathTex(
            f"\\lambda_{{max}} = {x_max:.0f}\\;\\mathrm{{nm}}",
            color=WHITE,
            font_size=28,
        ).next_to(punto_max, UP, buff=0.2)
        self.play(FadeIn(punto_max), Write(etiqueta_max))
        self.next_slide()

        self.wait()

# %% [markdown]
# ## Renderizar en Jupyter (cell magic)
#
# La siguiente celda solo funciona dentro de un Jupyter notebook en ejecución.

# %%
# %%manim_slides -v WARNING --progress_bar None DemoEspectro --manim-slides controls=true
#
# class DemoEspectro(Slide):
#     def construct(self):
#         titulo = Title("Espectro de absorción").to_corner(UL)
#         self.play(Write(titulo))
#         self.next_slide()
#
#         helper = ManimGraph(self)
#         axes = helper.setup_axes(
#             x_label=r"$\lambda ,(\mathrm{nm})$",
#             y_label="Absorbancia",
#             x_range=[300, 800, 50],
#             y_range=[0, 1.2, 0.2],
#         )
#         self.play(Create(axes))
#         self.next_slide()
#
#         curva_cruda = helper.plot_spectrum(data_path, color=BLUE, smooth=False)
#         self.play(Create(curva_cruda), run_time=2)
#         self.next_slide()
#
#         curva_suave = helper.plot_spectrum(data_path, color=GREEN, smooth=True)
#         self.play(Create(curva_suave), run_time=2)
#         self.next_slide()
#
#         leyenda = helper.create_legend([
#             {"text": "Crudo", "color": BLUE},
#             {"text": "Suavizado (Savitzky-Golay)", "color": GREEN},
#         ], position=UR)
#         self.play(Write(leyenda))
#         self.next_slide()
#
#         idx_max = int(np.argmax(y))
#         x_max, y_max = x[idx_max], y[idx_max]
#         punto_max = Dot(helper.axes.coords_to_point(x_max, y_max), color=RED)
#         etiqueta_max = MathTex(
#             f"\\lambda_{{max}} = {x_max:.0f}\\mathrm{{nm}}",
#             color=WHITE,
#             font_size=28,
#         ).next_to(punto_max, UP, buff=0.2)
#         self.play(FadeIn(punto_max), Write(etiqueta_max))
#         self.next_slide()
#
#         self.wait()
# Out:
# Manim Community v0.20.1
# [06/24/26 13:49:27] WARNING  one_file option is currently automatically enabled, because using ]8;id=10376448;file:///home/david-ibarra/miniconda3/envs/manim/lib/python3.14/site-packages/manim_slides/ipython/ipython_magic.py\ipython_magic.py]8;;\:]8;id=10376449;file:///home/david-ibarra/miniconda3/envs/manim/lib/python3.14/site-packages/manim_slides/ipython/ipython_magic.py#243\243]8;;\
#                              local video files does not seem to work properly.
# <div style="position:relative;padding-bottom:56.25%;"><iframe style="width:100%;height:100%;position:absolute;left:0px;top:0px;" frameborder="0" width="100%" height="100%" allowfullscreen allow="autoplay" src="media/jupyter/DemoEspectro@2026-06-24@13-49-27.html"></iframe></div>
