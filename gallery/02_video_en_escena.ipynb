# %% [markdown]
# # 02 — Video dentro de una escena
#
# `VideoMobject` envuelve un video como `ImageMobject` y lo actualiza
# frame a frame mediante un updater. Soporta control de velocidad y loop.
#
# ## Requisitos
#
# - `opencv-python` (`pip install opencv-python`)
# - `Pillow`
# - Un archivo de video en `figures/` (puedes usar el de la defensa).
#
# ## Notas
#
# - Si el video es muy pesado, el rendering será lento. Usa `--quality l` para iterar.
# - En `defensa_final.py` se desactiva `skip_reversing` para slides con video.

# %%
import sys
sys.path.insert(0, '..')

from manim import *
from manim_slides import Slide
from toolkit import VideoMobject

# %%
# %%manim_slides -qm DemoVideo
#
# class DemoVideo(Slide):
#     def construct(self):
#         # Reemplaza la ruta con tu propio video
#         # video = VideoMobject("figures/mi_video.mp4", speed=1.0, loop=True)
#         # video.height = 5
#         # self.add(video)
#         # self.next_slide(loop=True)
#         # self.wait(3)
#         # self.next_slide()
#
#         # Placeholder mientras no haya video cargado
#         placeholder = Text("Coloca un video en figures/\ny descomenta las líneas")
#         self.play(Write(placeholder))
#         self.next_slide()
#         self.wait()
