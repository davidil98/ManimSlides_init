# %% [markdown]
# # 04 — Estructuras químicas (pendiente)
#
# Este notebook está reservado para dibujar estructuras orgánicas en Manim.
#
# ## Opciones a evaluar
#
# 1. **RDKit + `Chem.Draw.rdMolDraw2D`**: genera imágenes 2D de alta calidad
#    desde SMILES. Luego se pueden importar como `ImageMobject` o
#    `SVGMobject`.
# 2. **Dibujo manual con primitivas Manim**: control total pero costoso en
#    tiempo. Útil para animaciones de reacciones paso a paso.
# 3. **Manim Chemistry (`manim-chemistry`)**:曾在某时修改过源码，
#    verificar si está mantenido y compatible con la versión actual.
# 4. **Py3Dmol** para vistas 3D interactivas embebidas.
#
# ## Pendiente
#
# - [ ] Decidir biblioteca(s) a usar.
# - [ ] Crear wrapper en `toolkit/chemistry.py`.
# - [ ] Ejemplo con una molécula sencilla (ej. benceno o cafeína).
# - [ ] Ejemplo de reacción (ej. SN2) con flechas curvas.

# %%
# Celda vacía: agregar aquí el código una vez que se decida la biblioteca.
pass
